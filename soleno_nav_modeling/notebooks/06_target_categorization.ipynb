# %% [markdown]
# # 06_target_categorization

# %%
import sys
from pathlib import Path
sys.path.insert(0, str(Path('.').resolve().parent))
from src.step06_categorization import run_step06
import pandas as pd
df=pd.read_csv('../outputs/tables/04_NAV_feature_engineered.csv')
run_step06(df)
